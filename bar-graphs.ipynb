# %%
import matplotlib.pyplot as plt
import pandas as pd
import csv

import load as ld

# %%
def draw_bar_graph_1(dataset: pd.DataFrame, cols: list) -> None:
    x = dataset[dataset[cols[1]] > 8]
    y = dataset[dataset[cols[1]] > 8]
    plt.plot(x, y)
    plt.legend()
    plt.show()

# %%
anime_dataset = ld.getData(ld.DATASET_PATH)

# %%
draw_bar_graph_1(anime_dataset, ["favorites", "score"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 draw_bar_graph_1(anime_dataset, ["favorites", "score"])
#
# Cell In[47], line 4, in draw_bar_graph_1(dataset, cols)
#       2 x = dataset[cols[0]]
#       3 y = dataset[dataset[cols[1]] > 8]
# ----> 4 plt.plot(x, y)
#       5 plt.legend()
#       6 plt.show()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/pyplot.py:3590, in plot(scalex, scaley, data, *args, **kwargs)
#    3582 @_copy_docstring_and_deprecators(Axes.plot)
#    3583 def plot(
#    3584     *args: float | ArrayLike | str,
#    (...)
#    3588     **kwargs,
#    3589 ) -> list[Line2D]:
# -> 3590     return gca().plot(
#    3591         *args,
#    3592         scalex=scalex,
#    3593         scaley=scaley,
#    3594         **({"data": data} if data is not None else {}),
# ...
